# %%
# Dependencies
import pandas as pd

# %%
# Load CSV file as dataframe
diseasedata = pd.read_csv("Resources/U.S._Chronic_Disease_Indicators__CDI_.csv")
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Preview the chronic diseases data
diseasedata.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# ...

# %%
# Choose the relevant columns
chronic_df = diseasedata[["YearEnd", "LocationDesc", "Topic", "Question", 
                          "DataValueUnit", "DataValueType", "DataValue", 
                          "Stratification1"]]

# %%
# Preview the revised dataframe
chronic_df.head()
# Out:
#    YearEnd   LocationDesc    Topic  \
# 0     2016  United States  Alcohol
# 1     2016        Alabama  Alcohol
# 2     2016         Alaska  Alcohol
# 3     2016        Arizona  Alcohol
# 4     2016       Arkansas  Alcohol
#
#                                             Question DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...             %
# 1  Binge drinking prevalence among adults aged >=...             %
# 2  Binge drinking prevalence among adults aged >=...             %
# 3  Binge drinking prevalence among adults aged >=...             %
# 4  Binge drinking prevalence among adults aged >=...             %
#
#       DataValueType DataValue Stratification1
# 0  Crude Prevalence      16.9         Overall
# 1  Crude Prevalence        13         Overall
# 2  Crude Prevalence      18.2         Overall
# 3  Crude Prevalence      15.6         Overall
# 4  Crude Prevalence        15         Overall

# %%
# Select data for 2010, 2012, and 2014
Years = [2010, 2012, 2014]
chronic_df2 = chronic_df[chronic_df["YearEnd"].isin(Years)]
chronic_df2.head()
# Out:
#         YearEnd   LocationDesc                   Topic  \
# 116756     2014       Kentucky  Chronic Kidney Disease
# 117030     2014      Louisiana  Chronic Kidney Disease
# 117178     2014          Texas  Chronic Kidney Disease
# 117329     2014  United States  Chronic Kidney Disease
# 117537     2014           Utah  Chronic Kidney Disease
#
#                                             Question        DataValueUnit  \
# 116756  Incidence of treated end-stage renal disease  cases per 1,000,000
# 117030  Incidence of treated end-stage renal disease  cases per 1,000,000
# 117178  Incidence of treated end-stage renal disease  cases per 1,000,000
# 117329  Incidence of treated end-stage renal disease  cases per 1,000,000
# 117537  Incidence of treated end-stage renal disease  cases per 1,000,000
#
#        DataValueType DataValue Stratification1
# 116756        Number      1749         Overall
# 117030        Number      2294         Overall
# ...

# %%
# Choose data for diabetes
chronic_df3 = chronic_df2[chronic_df2["Topic"] == "Diabetes"]
chronic_df3.head()
# Out:
#         YearEnd   LocationDesc     Topic  \
# 122531     2014  United States  Diabetes
# 160122     2012        Alabama  Diabetes
# 160139     2012           Iowa  Diabetes
# 160206     2012        Alabama  Diabetes
# 160309     2012       Delaware  Diabetes
#
#                                                  Question DataValueUnit  \
# 122531   Diabetes prevalence among women aged 18-44 years             %
# 160122  Prevalence of diagnosed diabetes among adults ...             %
# 160139   Diabetes prevalence among women aged 18-44 years             %
# 160206  Prevalence of diagnosed diabetes among adults ...             %
# 160309  Adults with diagnosed diabetes aged >= 18 year...             %
#
#                   DataValueType DataValue Stratification1
# 122531         Crude Prevalence       5.7         Overall
# 160122  Age-adjusted Prevalence      10.5        Hispanic
# 160139         Crude Prevalence       6.7         Overall
# ...

# %%
# Remove data for the US (we need state-wise data)
chronic_df4 = chronic_df3[chronic_df3["LocationDesc"]!="United States"]
chronic_df4.head()
# Out:
#         YearEnd  LocationDesc     Topic  \
# 160122     2012       Alabama  Diabetes
# 160139     2012          Iowa  Diabetes
# 160206     2012       Alabama  Diabetes
# 160309     2012      Delaware  Diabetes
# 160599     2012  Pennsylvania  Diabetes
#
#                                                  Question DataValueUnit  \
# 160122  Prevalence of diagnosed diabetes among adults ...             %
# 160139   Diabetes prevalence among women aged 18-44 years             %
# 160206  Prevalence of diagnosed diabetes among adults ...             %
# 160309  Adults with diagnosed diabetes aged >= 18 year...             %
# 160599  Prevalence of diagnosed diabetes among adults ...             %
#
#                   DataValueType DataValue Stratification1
# 160122  Age-adjusted Prevalence      10.5        Hispanic
# 160139         Crude Prevalence       6.7         Overall
# 160206  Age-adjusted Prevalence      11.9            Male
# ...

# %%
# Choose the data based on the following criteria:
# Crude Prevalence as the DataValueType
# Overall as the Stratification
chronic_df5 = chronic_df4.query("DataValueType == 'Crude Prevalence' & \
                                 Stratification1 == 'Overall'")
chronic_df5.head()
# Out:
#         YearEnd LocationDesc     Topic  \
# 160139     2012         Iowa  Diabetes
# 161003     2012         Guam  Diabetes
# 161379     2012       Alaska  Diabetes
# 161388     2012      Alabama  Diabetes
# 161396     2012     Arkansas  Diabetes
#
#                                                  Question DataValueUnit  \
# 160139   Diabetes prevalence among women aged 18-44 years             %
# 161003  Prevalence of diagnosed diabetes among adults ...             %
# 161379  Adults with diagnosed diabetes aged >= 18 year...             %
# 161388  Adults with diagnosed diabetes aged >= 18 year...             %
# 161396  Adults with diagnosed diabetes aged >= 18 year...             %
#
#            DataValueType DataValue Stratification1
# 160139  Crude Prevalence       6.7         Overall
# 161003  Crude Prevalence       9.6         Overall
# 161379  Crude Prevalence      71.1         Overall
# 161388  Crude Prevalence      53.7         Overall
# ...

# %%
# Choose data with Question as "Prevalence of diagnosed diabetes among adults aged >= 18 years"
chronic_df6 = chronic_df5[chronic_df5["Question"] == "Prevalence of diagnosed diabetes \
among adults aged >= 18 years"]

chronic_df6.head()
# Out:
#         YearEnd LocationDesc     Topic  \
# 161003     2012         Guam  Diabetes
# 166619     2012       Alaska  Diabetes
# 166627     2012      Alabama  Diabetes
# 166635     2012     Arkansas  Diabetes
# 166643     2012      Arizona  Diabetes
#
#                                                  Question DataValueUnit  \
# 161003  Prevalence of diagnosed diabetes among adults ...             %
# 166619  Prevalence of diagnosed diabetes among adults ...             %
# 166627  Prevalence of diagnosed diabetes among adults ...             %
# 166635  Prevalence of diagnosed diabetes among adults ...             %
# 166643  Prevalence of diagnosed diabetes among adults ...             %
#
#            DataValueType DataValue Stratification1
# 161003  Crude Prevalence       9.6         Overall
# 166619  Crude Prevalence         7         Overall
# 166627  Crude Prevalence      12.2         Overall
# 166635  Crude Prevalence      11.3         Overall
# ...

# %%
# Rename columns for clarity
chronic_df6 = chronic_df6.rename(columns = {"YearEnd": "Year",
                                            "LocationDesc": "US_State",
                                            "DataValue": "Adult_Diabetics_%"})
chronic_df6.head()
# Out:
#         Year  US_State     Topic  \
# 161003  2012      Guam  Diabetes
# 166619  2012    Alaska  Diabetes
# 166627  2012   Alabama  Diabetes
# 166635  2012  Arkansas  Diabetes
# 166643  2012   Arizona  Diabetes
#
#                                                  Question DataValueUnit  \
# 161003  Prevalence of diagnosed diabetes among adults ...             %
# 166619  Prevalence of diagnosed diabetes among adults ...             %
# 166627  Prevalence of diagnosed diabetes among adults ...             %
# 166635  Prevalence of diagnosed diabetes among adults ...             %
# 166643  Prevalence of diagnosed diabetes among adults ...             %
#
#            DataValueType Adult_Diabetics_% Stratification1
# 161003  Crude Prevalence               9.6         Overall
# 166619  Crude Prevalence                 7         Overall
# 166627  Crude Prevalence              12.2         Overall
# 166635  Crude Prevalence              11.3         Overall
# ...

# %%
# Remove more columns after renaming columns
chronic_df7 = chronic_df6[["Year", "US_State", "Adult_Diabetics_%"]]
chronic_df7
# Out:
#         Year              US_State Adult_Diabetics_%
# 161003  2012                  Guam               9.6
# 166619  2012                Alaska                 7
# 166627  2012               Alabama              12.2
# 166635  2012              Arkansas              11.3
# 166643  2012               Arizona              10.6
# 166651  2012            California               9.8
# 166659  2012              Colorado               7.4
# 166667  2012           Connecticut               9.1
# 166675  2012  District of Columbia               8.2
# 166683  2012              Delaware               9.6
# 166691  2012               Florida              11.4
# 166699  2012               Georgia               9.9
# 166714  2012                Hawaii               7.8
# 166722  2012                  Iowa               9.7
# 166731  2012                 Idaho               8.5
# 166739  2012              Illinois               9.4
# 166747  2012               Indiana              10.9
# ...

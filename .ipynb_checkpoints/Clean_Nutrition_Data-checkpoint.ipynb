# %% [markdown]
# ## Extract data from csv files

# %%
# Dependencies
import pandas as pd

# %%
# Load CSV file as dataframe
nutr_df = pd.read_csv("Resources/Nutrition__Physical_Activity__and_Obesity_-_Women__Infant__and_Child.csv")
nutr_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9a8d2fe0bd24> in <module>()
#       1 # Load CSV file as dataframe
# ----> 2 nutr_df = pd.read_csv("Resources/Nutrition__Physical_Activity__and_Obesity_-_Women__Infant__and_Child.csv")
#       3 nutr_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Resources/Nutrition__Physical_Activity__and_Obesity_-_Women__Infant__and_Child.csv' does not exist

# %% [markdown]
# ## Transform data

# %%
# Get a list of column headers
list(nutr_df)
# Out:
# ['YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'Datasource',
#  'Class',
#  'Topic',
#  'Question',
#  'Data_Value_Unit',
#  'Data_Value_Type',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit ',
#  'Sample_Size',
#  'Total',
#  'Age(months)',
#  'Gender',
#  'Race/Ethnicity',
#  'GeoLocation',
#  'ClassID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'LocationID',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategoryId1',
#  'StratificationID1']

# %%
# Get the relevant columns
nutr_df2 = nutr_df[["YearEnd", "LocationAbbr", "LocationDesc", "Question", "Data_Value", 
                    "StratificationID1"]]
nutr_df2.head()
# Out:
#    YearEnd LocationAbbr LocationDesc  \
# 0     2008           AL      Alabama
# 1     2008           AL      Alabama
# 2     2008           AL      Alabama
# 3     2008           AL      Alabama
# 4     2008           AL      Alabama
#
#                                             Question  Data_Value  \
# 0  Percent of WIC children aged 2 to 4 years who ...        15.4
# 1  Percent of WIC children aged 2 to 4 years who ...        15.5
# 2  Percent of WIC children aged 2 to 4 years who ...        15.3
# 3  Percent of WIC children aged 2 to 4 years who ...        15.3
# 4  Percent of WIC children aged 2 to 4 years who ...        14.9
#
#   StratificationID1
# 0           OVERALL
# 1              MALE
# 2            FEMALE
# 3         AGEMO2435
# 4         AGEMO3647

# %%
# Choose data for 2010, 2012, and 2014
Years = [2010, 2012, 2014]

nutr_df3 = nutr_df2[nutr_df2["YearEnd"].isin(Years)]
nutr_df3.head()
# Out:
#     YearEnd LocationAbbr LocationDesc  \
# 11     2010           AL      Alabama
# 12     2010           AL      Alabama
# 13     2010           AL      Alabama
# 14     2010           AL      Alabama
# 15     2010           AL      Alabama
#
#                                              Question  Data_Value  \
# 11  Percent of WIC children aged 2 to 4 years who ...        16.0
# 12  Percent of WIC children aged 2 to 4 years who ...        16.3
# 13  Percent of WIC children aged 2 to 4 years who ...        15.8
# 14  Percent of WIC children aged 2 to 4 years who ...        15.5
# 15  Percent of WIC children aged 2 to 4 years who ...        16.3
#
#    StratificationID1
# 11           OVERALL
# 12              MALE
# 13            FEMALE
# 14         AGEMO2435
# 15         AGEMO3647

# %%
# Choose data with no stratification (stratification ID1 = "overall") 
# and choose values for obese children 2-4 yo
nutr_df4 = nutr_df3.query("StratificationID1 == 'OVERALL'& \
                          Question == 'Percent of WIC children aged 2 to 4 years who have obesity'")
nutr_df4.head()
# Out:
#      YearEnd LocationAbbr LocationDesc  \
# 58      2010           AL      Alabama
# 66      2012           AL      Alabama
# 82      2014           AL      Alabama
# 155     2010           AK       Alaska
# 166     2012           AK       Alaska
#
#                                               Question  Data_Value  \
# 58   Percent of WIC children aged 2 to 4 years who ...        15.8
# 66   Percent of WIC children aged 2 to 4 years who ...        15.6
# 82   Percent of WIC children aged 2 to 4 years who ...        16.3
# 155  Percent of WIC children aged 2 to 4 years who ...        21.2
# 166  Percent of WIC children aged 2 to 4 years who ...        20.6
#
#     StratificationID1
# 58            OVERALL
# 66            OVERALL
# 82            OVERALL
# 155           OVERALL
# 166           OVERALL

# %%
# Further clean the dataset
nutr_df4 = nutr_df4[["YearEnd", "LocationDesc", "Data_Value"]]

# Rename the remaining columns
nutr_df4 = nutr_df4.rename(columns = {"YearEnd": "Year",
                                      "LocationDesc": "US_State",
                                      "Data_Value": "Obese_Children_%"})

# Preview the dataframe
nutr_df4.head()
# Out:
#      Year US_State  Obese_Children_%
# 58   2010  Alabama              15.8
# 66   2012  Alabama              15.6
# 82   2014  Alabama              16.3
# 155  2010   Alaska              21.2
# 166  2012   Alaska              20.6

# %%
# Create a table of Location Abbreviations and Descriptions (unique values only)
location = nutr_df4[["US_State"]].drop_duplicates()

# Preview the dataframe
location
# Out:
#                   US_State
# 58                 Alabama
# 155                 Alaska
# 255                Arizona
# 356               Arkansas
# 458             California
# 558               Colorado
# 659            Connecticut
# 759               Delaware
# 859   District of Columbia
# 959                Florida
# 1059               Georgia
# 1159                Hawaii
# 1259                 Idaho
# 1359              Illinois
# 1459               Indiana
# 1559                  Iowa
# 1659                Kansas
# 1760              Kentucky
# 1860             Louisiana
# 1959                 Maine
# 2059              Maryland
# 2159         Massachusetts
# 2249              Michigan
# 2360             Minnesota
# 2459           Mississippi
# 2509              Missouri
# 2659               Montana
# 2760              Nebraska
# 2859                Nevada
# 2959         New Hampshire
# 3059            New Jersey
# 3160            New Mexico
# 3259              New York
# 3349        North Carolina
# 3459          North Dakota
# 3559                  Ohio
# 3659              Oklahoma
# 3760                Oregon
# 3859          Pennsylvania
# 3959          Rhode Island
# 4060        South Carolina
# 4148          South Dakota
# 4256             Tennessee
# 4355                 Texas
# 4455                  Utah
# 4555               Vermont
# 4655              Virginia
# 4755            Washington
# 4855         West Virginia
# 4956             Wisconsin
# 5056               Wyoming
# 5150                  Guam
# 5247           Puerto Rico
# 5345        Virgin Islands

# %% [markdown]
# ## Load data into database

# %%
# Dependencies
from sqlalchemy import create_engine
from config import password

# %%
# Create a connection to the database
conn = "root:{0}@localhost:3306/diabetes_db".format(password) # Password is in a separate file
engine = create_engine(f"mysql://{conn}")

# %%
# Confirm presence of tables
engine.table_names()

# %%
# Load dataframes into tables
location.to_sql(name = "location", con = engine, if_exists = "replace", index = False)
nutr_df4.to_sql(name = "nutrition", con = engine, if_exists = "replace", index = False)

# %%
# Read the table contents (for location)
pd.read_sql_query("select * from location").head()

# %%
# Read the table contents (for nutrition)
pd.read_sql_query("select * from nutrition").head()
